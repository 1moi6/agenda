# %%
import requests
import json
from faker import Faker
import random
from datetime import datetime, timedelta
import time

# %%
# faz login
access = {}
url = 'http://127.0.0.1:8000/auth/api/token/'
dados = {'email':"moiseis@gmail.com",'password':'saralice','username':'moiseis'}
x = requests.post(url, json = dados)
tokens = json.loads(x.text)

access["moiseis"] = tokens["access"]

dados = {'email':"rodolfo@gmail.com",'password':'rodolfo123','username':'rodolfo'}
x = requests.post(url, json = dados)
tokens = json.loads(x.text)
access["rodolfo"] = tokens["access"]

# %%
# cria pacientes
url = 'http://127.0.0.1:8000/agendasis/api/pacientes/'
headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access["moiseis"]}'}
fake = Faker()
data = {}

hoje =  datetime.now().date()
for i in range(200):
    headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access[random.choice(["rodolfo","moiseis"])]}'}
    nome=fake.name()
    nascimento=fake.date_of_birth(minimum_age=18, maximum_age=90)
    idade =  hoje.year - nascimento.year - ((hoje.month, hoje.day) < (nascimento.month, nascimento.day))
    naturalidade=fake.city()
    nacionalidade=fake.country()
    sexo=random.choice(["Masculino", "Feminino"])
    cor=fake.color_name()
    estadocivil=random.choice(["Solteiro(a)", "Casado(a)", "Divorciado(a)", "Viúvo(a)"])
    profissao=fake.job()
    telefone1=fake.phone_number()
    telefone2=fake.phone_number()
    email1=fake.email()
    email2=fake.email()
    cpf=fake.unique.random_int(min=10000000000, max=99999999999)
    rg=fake.random_int(min=100000000, max=999999999)
    rg_emissor=fake.random_element(elements=("SSP", "DETRAN", "IFP", "PF"))
    cns=fake.random_int(min=100000000000000, max=999999999999999)
    cep=fake.zipcode()
    endereco=fake.address()
    mae=fake.first_name_female()
    pai=fake.first_name_male()
    responsavel=fake.name()
    observacoes=fake.text()
    data = {"nome":nome,"nascimento":nascimento.strftime('%Y-%m-%d'),"idade":idade,"naturalidade":naturalidade,
           "nacionalidade":nacionalidade,"sexo":sexo,"cor":cor,"estadocivil":estadocivil, "profissao":profissao,
            "telefone1":telefone1,"telefone2":telefone2,"email1":email1,"email2":email2,"cpf":cpf,"rg":rg,
             "rg_emissor":rg_emissor,"cns":cns,"cep":cep,"endereco":endereco,"mae":mae,"pai":pai,
              "responsavel":responsavel,"observacoes":observacoes}
    r = requests.post(url,headers=headers,json = data)
    print(r.text)
# Out:
# {"id":1,"nome":"Phillip Poole","nascimento":"1962-02-11","idade":61,"naturalidade":"East James","nacionalidade":"Kuwait","sexo":"Feminino","cor":"Chocolate","estadocivil":"Casado(a)","profissao":"Best boy","telefone1":"696-268-9578x67744","telefone2":"705-430-2360","email1":"silvajohn@example.com","email2":"joe65@example.org","cpf":"19439780567","rg":"149917675","rg_emissor":"PF","cns":"586460698472854","cep":"36920","endereco":"94877 Jon Expressway Suite 086\nLindsayfort, MA 02482","mae":"Shelley","pai":"David","responsavel":"Thomas Miller","observacoes":"Piece writer finish minute decide beyond drug. Consider reduce might draw she. Here method need of good.\nNearly speak food outside. Experience service partner involve each eight opportunity."}
# {"id":2,"nome":"Jonathan Cline","nascimento":"1963-05-09","idade":60,"naturalidade":"Garrettside","nacionalidade":"Nicaragua","sexo":"Feminino","cor":"SkyBlue","estadocivil":"Solteiro(a)","profissao":"Advertising account planner","telefone1":"642.908.0347x83987","telefone2":"+1-622-844-8439x76410","email1":"mmccoy@example.org","email2":"sarah12@example.org","cpf":"83433772782","rg":"817171936","rg_emissor":"SSP","cns":"235141622433785","cep":"32459","endereco":"53884 Tran Street Suite 761\nPort Cameronborough, CA 87987","mae":"Julie","pai":"Brandon","responsavel":"Raymond Brown","observacoes":"Newspaper central western yeah fast spend. Civil represent listen free.\nHundred bar air figure. Home idea visit cold soldier. Land receive financial get watch."}
# {"id":3,"nome":"William Smith","nascimento":"1937-09-09","idade":86,"naturalidade":"South Lee","nacionalidade":"Burundi","sexo":"Masculino","cor":"PaleTurquoise","estadocivil":"Casado(a)","profissao":"Games developer","telefone1":"732.443.0583","telefone2":"4809096974","email1":"wwilliams@example.org","email2":"ychavez@example.org","cpf":"31186867736","rg":"625042759","rg_emissor":"SSP","cns":"648097965665720","cep":"96310","endereco":"1365 Huffman Ports Apt. 915\nGreenhaven, MT 29579","mae":"Samantha","pai":"John","responsavel":"Sheila Richardson","observacoes":"Usually agency card reduce.\nWife behind situation car miss meet. Hear security sport majority science war."}
# {"id":4,"nome":"Heidi Butler","nascimento":"1952-10-09","idade":71,"naturalidade":"Katiemouth","nacionalidade":"Turkey","sexo":"Feminino","cor":"Beige","estadocivil":"Solteiro(a)","profissao":"Financial controller","telefone1":"+1-438-277-7634x63121","telefone2":"981.994.5287x12186","email1":"mark36@example.com","email2":"smorales@example.org","cpf":"60594462126","rg":"643277183","rg_emissor":"SSP","cns":"853994864379436","cep":"83082","endereco":"95158 Heather Plain Apt. 832\nEast Jocelyn, MA 36587","mae":"Heather","pai":"Chad","responsavel":"Megan Fisher","observacoes":"Mind together activity often ever seat power. People if care control onto cup base. Month add science resource."}
# {"id":5,"nome":"Mrs. Crystal Green DDS","nascimento":"2001-08-04","idade":22,"naturalidade":"Paultown","nacionalidade":"Seychelles","sexo":"Masculino","cor":"LightGreen","estadocivil":"Casado(a)","profissao":"Manufacturing systems engineer","telefone1":"+1-313-982-1486x492","telefone2":"+1-615-382-9403x65872","email1":"william81@example.net","email2":"perry80@example.net","cpf":"65101434272","rg":"164408162","rg_emissor":"DETRAN","cns":"379387942418784","cep":"15312","endereco":"28149 Alison Rapid\nHodgesside, IN 05227","mae":"Traci","pai":"Dakota","responsavel":"Denise Wagner","observacoes":"Believe professor add charge summer well.\nSide best different near law. Place finally material political government figure prevent. Thought herself bed benefit production."}
# {"id":6,"nome":"Mr. Robert Ruiz","nascimento":"2002-06-11","idade":21,"naturalidade":"Port Jacobfort","nacionalidade":"Jordan","sexo":"Feminino","cor":"LightSlateGray","estadocivil":"Viúvo(a)","profissao":"Editorial assistant","telefone1":"383-883-3104x1534","telefone2":"925.391.2285","email1":"knelson@example.org","email2":"hlopez@example.com","cpf":"45917317681","rg":"575276991","rg_emissor":"PF","cns":"235740728382061","cep":"44249","endereco":"1712 Michael Hill Suite 276\nNorth Nicoleland, IA 18097","mae":"Amanda","pai":"Duane","responsavel":"Anthony Ramirez","observacoes":"No will man information computer suggest. Here all guy chance.\nOrder carry result case south again bar. Seek member concern although less. Country school career."}
# {"id":7,"nome":"Peter Wright","nascimento":"1950-08-06","idade":73,"naturalidade":"West Michealshire","nacionalidade":"Luxembourg","sexo":"Masculino","cor":"DarkGreen","estadocivil":"Casado(a)","profissao":"Surveyor, mining","telefone1":"(610)838-7570","telefone2":"752-436-1359","email1":"lisamurphy@example.com","email2":"justinlittle@example.org","cpf":"12419281509","rg":"191675376","rg_emissor":"SSP","cns":"183279798403565","cep":"33382","endereco":"585 Richard Radial Apt. 472\nWhitakerstad, MN 18286","mae":"Linda","pai":"David","responsavel":"Kevin Strickland","observacoes":"Crime letter pattern former town.\nKid work send action us laugh. Apply school with to century personal authority."}
# {"id":8,"nome":"Andrea Jones","nascimento":"2005-05-03","idade":18,"naturalidade":"Lake Jacobburgh","nacionalidade":"Reunion","sexo":"Masculino","cor":"LightGoldenRodYellow","estadocivil":"Casado(a)","profissao":"Technical brewer","telefone1":"+1-634-835-2555x186","telefone2":"+1-496-686-2922","email1":"steve63@example.org","email2":"raymondshea@example.com","cpf":"13321789808","rg":"825027021","rg_emissor":"IFP","cns":"336485550001617","cep":"64070","endereco":"2731 Heather Plains Apt. 430\nLake Victoriaberg, VI 35903","mae":"Kim","pai":"Caleb","responsavel":"Tara Castro","observacoes":"Truth citizen side difference reduce traditional design. Everyone analysis standard listen visit."}
# {"id":9,"nome":"Christopher Mcbride","nascimento":"1981-11-26","idade":41,"naturalidade":"Mistyhaven","nacionalidade":"Ireland","sexo":"Feminino","cor":"BlueViolet","estadocivil":"Casado(a)","profissao":"Chiropractor","telefone1":"001-245-365-7817x97085","telefone2":"+1-581-937-1139x01794","email1":"svaughn@example.org","email2":"patrickrobinson@example.org","cpf":"47169905255","rg":"811508173","rg_emissor":"SSP","cns":"612498335995540","cep":"36785","endereco":"PSC 5175, Box 6581\nAPO AP 78503","mae":"Sarah","pai":"Benjamin","responsavel":"Betty Wilson","observacoes":"Process provide management doctor challenge model. Dog money day never understand piece minute.\nAudience within bag several address manager whole. Onto appear walk field candidate once series."}
# {"id":10,"nome":"Elijah Terrell DDS","nascimento":"1984-06-10","idade":39,"naturalidade":"Finleystad","nacionalidade":"Saint Helena","sexo":"Feminino","cor":"MediumOrchid","estadocivil":"Divorciado(a)","profissao":"Make","telefone1":"(687)364-5996","telefone2":"3375430849","email1":"moniquechen@example.net","email2":"cbarnett@example.org","cpf":"43148785550","rg":"714917079","rg_emissor":"IFP","cns":"459997114052707","cep":"05455","endereco":"532 Henry Inlet Suite 667\nSarahland, PW 50658","mae":"Carolyn","pai":"Christopher","responsavel":"Lisa Kemp","observacoes":"Later art worker really discover subject think tonight. Certain work game suddenly.\nMoment possible whole interest difference language piece. Different gun rich investment close business test."}
# {"id":11,"nome":"Rick Sanchez","nascimento":"1957-04-05","idade":66,"naturalidade":"Justinmouth","nacionalidade":"Azerbaijan","sexo":"Masculino","cor":"Ivory","estadocivil":"Solteiro(a)","profissao":"Psychologist, prison and probation services","telefone1":"+1-287-995-2692","telefone2":"(992)289-7299x851","email1":"vjohnson@example.org","email2":"simonsydney@example.com","cpf":"89920651048","rg":"773412740","rg_emissor":"IFP","cns":"285172171061399","cep":"46682","endereco":"94608 Walton Forges Apt. 068\nNguyenmouth, GA 84569","mae":"Stephanie","pai":"Steven","responsavel":"Amy Pacheco","observacoes":"Office car these personal hotel main. Computer institution because season another. Accept citizen hear rock wind while high.\nMinute any various exactly do great truth do. Want by word nor will bed."}
# {"id":12,"nome":"Samantha Matthews","nascimento":"1965-05-18","idade":58,"naturalidade":"Janiceton","nacionalidade":"Kyrgyz Republic","sexo":"Feminino","cor":"Snow","estadocivil":"Divorciado(a)","profissao":"Counsellor","telefone1":"001-581-535-2378x170","telefone2":"828.917.8565","email1":"vmcconnell@example.org","email2":"blake08@example.com","cpf":"94906436795","rg":"821300974","rg_emissor":"IFP","cns":"144060802773466","cep":"91611","endereco":"91416 Simpson Port\nTorresview, NC 83199","mae":"Andrea","pai":"Robert","responsavel":"Monica Patel","observacoes":"Pass whose improve form particular product able. Loss involve direction data occur wall ever blue. Role cost team western big ability increase."}
# {"id":13,"nome":"George Smith","nascimento":"1968-03-30","idade":55,"naturalidade":"Howardville","nacionalidade":"France","sexo":"Masculino","cor":"SlateGray","estadocivil":"Casado(a)","profissao":"Armed forces logistics/support/administrative officer","telefone1":"+1-370-765-0276x24216","telefone2":"287.595.9799","email1":"kristen45@example.com","email2":"jsanchez@example.net","cpf":"17824764538","rg":"862284767","rg_emissor":"SSP","cns":"354466944113818","cep":"52051","endereco":"90217 Steven Squares\nChanport, MN 37075","mae":"Heather","pai":"Gregory","responsavel":"Cody Hicks","observacoes":"Great ahead nor blood major key rule international. While reality discover child allow.\nThere blue involve fill fast poor style. Nothing ask seven."}
# {"id":14,"nome":"Rebecca Brady","nascimento":"1975-04-15","idade":48,"naturalidade":"Blairborough","nacionalidade":"Nicaragua","sexo":"Feminino","cor":"Maroon","estadocivil":"Viúvo(a)","profissao":"Radiographer, diagnostic","telefone1":"+1-524-745-1972","telefone2":"+1-656-562-1129x437","email1":"apittman@example.com","email2":"kingsylvia@example.org","cpf":"70428445767","rg":"785043149","rg_emissor":"IFP","cns":"130782640133576","cep":"86595","endereco":"44313 Nicole Overpass\nEast Christinemouth, FM 32767","mae":"Maureen","pai":"Michael","responsavel":"Cynthia Peterson","observacoes":"Magazine item budget area perhaps Democrat instead. Reflect indeed glass safe. Administration cold police whole threat. Including after wait machine site easy."}
# {"id":15,"nome":"Duane Herman","nascimento":"2000-11-25","idade":22,"naturalidade":"Websterton","nacionalidade":"Iceland","sexo":"Feminino","cor":"Magenta","estadocivil":"Divorciado(a)","profissao":"Financial risk analyst","telefone1":"862.684.4330x38473","telefone2":"001-318-487-5093x250","email1":"perryberger@example.com","email2":"brownrobert@example.com","cpf":"66348780701","rg":"174195360","rg_emissor":"DETRAN","cns":"373602958041357","cep":"27616","endereco":"1578 Jonathan Pines\nTabithafurt, IN 77177","mae":"Tammy","pai":"David","responsavel":"Anthony Ross","observacoes":"Design be production current myself past two eat. Serious material music describe.\nMonth rule his. Drop bed always leg attorney. Concern rate situation say computer couple."}
# {"id":16,"nome":"Paul Olson","nascimento":"1964-10-30","idade":59,"naturalidade":"East Peggymouth","nacionalidade":"Uganda","sexo":"Masculino","cor":"Ivory","estadocivil":"Divorciado(a)","profissao":"Network engineer","telefone1":"+1-920-812-1476x778","telefone2":"925.290.2695x041","email1":"jessicagates@example.org","email2":"lsimon@example.com","cpf":"60866223638","rg":"304615363","rg_emissor":"DETRAN","cns":"789211779719813","cep":"83750","endereco":"3418 Greene Ranch\nKevinside, TX 92569","mae":"Christine","pai":"Jason","responsavel":"Matthew Turner","observacoes":"Southern box girl mouth. Care reach animal including.\nCitizen scientist describe house foreign whether."}
# {"id":17,"nome":"Jennifer Lloyd","nascimento":"2003-02-28","idade":20,"naturalidade":"Tammyview","nacionalidade":"Tonga","sexo":"Masculino","cor":"Crimson","estadocivil":"Solteiro(a)","profissao":"Systems developer","telefone1":"3447907410","telefone2":"+1-542-393-1904","email1":"kellywilliams@example.com","email2":"owade@example.com","cpf":"63120716700","rg":"571226130","rg_emissor":"SSP","cns":"414911841615261","cep":"68244","endereco":"96891 Payne Haven\nNew Katiemouth, UT 29664","mae":"Hannah","pai":"Allen","responsavel":"Michael Bailey","observacoes":"Just end foot. Per film remain kid. Bring watch assume read about.\nAnd local training send that. Game gas knowledge. Including produce property own case wonder effort himself."}
# {"id":18,"nome":"William Larsen","nascimento":"1949-04-09","idade":74,"naturalidade":"South Thomas","nacionalidade":"Cape Verde","sexo":"Feminino","cor":"Black","estadocivil":"Solteiro(a)","profissao":"Patent examiner","telefone1":"911.601.0408x75147","telefone2":"+1-727-815-3426","email1":"alvarezsteven@example.net","email2":"frostcrystal@example.org","cpf":"24210918243","rg":"844328182","rg_emissor":"DETRAN","cns":"676008604745569","cep":"37190","endereco":"43130 Eric Roads\nLake Joshua, SD 03999","mae":"Madison","pai":"Jerry","responsavel":"Allison Morgan","observacoes":"Best rule take president benefit garden clear. Through fire manager. Resource ok want hospital quite."}
# {"id":19,"nome":"Kathryn Duncan","nascimento":"1967-01-26","idade":56,"naturalidade":"Michaelport","nacionalidade":"Belize","sexo":"Feminino","cor":"Aquamarine","estadocivil":"Divorciado(a)","profissao":"Scientist, biomedical","telefone1":"255.980.9829","telefone2":"934-513-5941x54179","email1":"bramirez@example.com","email2":"pwatson@example.net","cpf":"90969486244","rg":"134755022","rg_emissor":"IFP","cns":"802162252130915","cep":"21289","endereco":"975 Green Parks\nSouth Pamelafort, CA 87907","mae":"Amber","pai":"Bruce","responsavel":"Joseph Smith","observacoes":"Whose treat better can seat buy but. Single sport argue morning remain although.\nSort office prove PM recently. Talk technology fill here learn. State operation enough on page."}
# {"id":20,"nome":"Tonya Brown","nascimento":"1961-05-28","idade":62,"naturalidade":"Smithshire","nacionalidade":"Zambia","sexo":"Feminino","cor":"OldLace","estadocivil":"Viúvo(a)","profissao":"Food technologist","telefone1":"579.892.3157","telefone2":"001-645-728-1666x866","email1":"moorejoseph@example.org","email2":"xsmith@example.com","cpf":"59657652760","rg":"498960328","rg_emissor":"IFP","cns":"546123985305293","cep":"90139","endereco":"859 Baldwin Key Apt. 857\nAmyside, NY 44589","mae":"Elizabeth","pai":"Stephen","responsavel":"Dominic Price","observacoes":"By local task good.\nPer apply she teach.\nToday all threat arrive common. Within blue little street condition movie establish. Interest general religious treatment meeting."}
# {"id":21,"nome":"David Hobbs","nascimento":"1955-06-24","idade":68,"naturalidade":"South Susanfort","nacionalidade":"Monaco","sexo":"Masculino","cor":"LimeGreen","estadocivil":"Solteiro(a)","profissao":"Runner, broadcasting/film/video","telefone1":"001-671-497-3385x6558","telefone2":"+1-553-310-0645x37658","email1":"kjohnson@example.org","email2":"anna32@example.net","cpf":"78420205860","rg":"180117311","rg_emissor":"SSP","cns":"743152559543233","cep":"04693","endereco":"82427 Dawn Spurs Suite 092\nStephanieview, SD 53719","mae":"Rebecca","pai":"James","responsavel":"Kelly Hall","observacoes":"Move difference store yet method space. Skin itself reach career international tough stage professional."}
# {"id":22,"nome":"Tammy Lewis","nascimento":"1958-02-11","idade":65,"naturalidade":"Claudiaview","nacionalidade":"Peru","sexo":"Masculino","cor":"Thistle","estadocivil":"Viúvo(a)","profissao":"Advertising account executive","telefone1":"863-855-3489x25664","telefone2":"001-209-508-8512x1443","email1":"kevin63@example.org","email2":"shoffman@example.net","cpf":"33000918019","rg":"964292056","rg_emissor":"DETRAN","cns":"797838292785065","cep":"74829","endereco":"774 Moran Groves\nShafferland, SD 17241","mae":"Karen","pai":"Nathan","responsavel":"Mr. Michael Buchanan","observacoes":"Pattern could its speak manager. Anyone near data general prepare general. Do leave wrong time."}
# {"id":23,"nome":"Cameron Munoz","nascimento":"1999-01-17","idade":24,"naturalidade":"Schmidtstad","nacionalidade":"Jordan","sexo":"Feminino","cor":"AntiqueWhite","estadocivil":"Casado(a)","profissao":"Conference centre manager","telefone1":"4623105716","telefone2":"685-773-8662x2606","email1":"sfreeman@example.com","email2":"romerokrista@example.net","cpf":"32384331141","rg":"504206324","rg_emissor":"DETRAN","cns":"245969376960415","cep":"08513","endereco":"0600 Smith Union\nNew Jesse, MN 50932","mae":"Claudia","pai":"Michael","responsavel":"Amanda Gonzalez","observacoes":"Available loss note product level area. Card TV resource inside best. Over law his around.\nManager director suffer threat. Attention quite opportunity south."}
# {"id":24,"nome":"Amber Walters","nascimento":"1994-10-28","idade":29,"naturalidade":"Port Amanda","nacionalidade":"Falkland Islands (Malvinas)","sexo":"Feminino","cor":"DarkViolet","estadocivil":"Casado(a)","profissao":"Lecturer, higher education","telefone1":"(916)892-3412x07582","telefone2":"+1-253-406-4693x282","email1":"rharris@example.net","email2":"alexandra90@example.org","cpf":"31122505649","rg":"262588719","rg_emissor":"IFP","cns":"288640522834379","cep":"58359","endereco":"28948 Victor Landing Apt. 385\nNicoleland, MN 51920","mae":"Jessica","pai":"Chris","responsavel":"Justin Woodward","observacoes":"Tough type across individual. Impact wife door gas model media. Pm wind student blue finish. Car way because least about cold."}
# {"id":25,"nome":"Beverly Martin","nascimento":"1983-06-24","idade":40,"naturalidade":"Brooksland","nacionalidade":"British Indian Ocean Territory (Chagos Archipelago)","sexo":"Masculino","cor":"DarkSalmon","estadocivil":"Divorciado(a)","profissao":"Radiographer, diagnostic","telefone1":"+1-455-343-1103x458","telefone2":"843.457.2833x929","email1":"cindy53@example.com","email2":"agutierrez@example.org","cpf":"87379282079","rg":"854497399","rg_emissor":"PF","cns":"108435849553582","cep":"23396","endereco":"8463 Christina Coves\nJodifurt, NY 82516","mae":"Stephanie","pai":"Robert","responsavel":"Trevor Garcia","observacoes":"Teach simply south college fine future social. Can tell go no day cover quite. Trade investment data one capital benefit ground instead.\nLetter we usually minute offer. Town take girl year."}
# {"id":26,"nome":"Jacob Rodriguez","nascimento":"1992-07-13","idade":31,"naturalidade":"Stephanieside","nacionalidade":"Cook Islands","sexo":"Feminino","cor":"SkyBlue","estadocivil":"Divorciado(a)","profissao":"Nurse, children's","telefone1":"(236)764-8076x81375","telefone2":"619.662.0292","email1":"kristinecarroll@example.com","email2":"sjohnson@example.com","cpf":"39753973577","rg":"959947652","rg_emissor":"IFP","cns":"519928951010060","cep":"30117","endereco":"6805 Hill Cape Suite 927\nSouth Joshua, NC 05373","mae":"Ashley","pai":"Jonathan","responsavel":"Brian Scott","observacoes":"Ok certainly plan north industry production. Short against interesting Mr. Attorney address news would suffer. Too final look trip apply for generation."}
# {"id":27,"nome":"Amy Fields","nascimento":"1978-04-06","idade":45,"naturalidade":"West Derektown","nacionalidade":"Papua New Guinea","sexo":"Feminino","cor":"LightCoral","estadocivil":"Viúvo(a)","profissao":"Ship broker","telefone1":"868-806-8092x89151","telefone2":"001-356-497-5974","email1":"sandracooke@example.org","email2":"troyolson@example.net","cpf":"83362247716","rg":"669962833","rg_emissor":"PF","cns":"330114193512729","cep":"71356","endereco":"USNS Forbes\nFPO AE 10264","mae":"Lauren","pai":"Brandon","responsavel":"Susan Reid DDS","observacoes":"Less cost student ahead. Property air look police. Guy public general eat article heavy beautiful."}
# {"id":28,"nome":"Jennifer Mcdonald","nascimento":"1991-05-09","idade":32,"naturalidade":"North Natasha","nacionalidade":"Bangladesh","sexo":"Feminino","cor":"MediumSeaGreen","estadocivil":"Divorciado(a)","profissao":"Chemical engineer","telefone1":"630.657.6585","telefone2":"987.846.1957x825","email1":"russellmelanie@example.com","email2":"isimmons@example.org","cpf":"97283860691","rg":"241641233","rg_emissor":"SSP","cns":"903416002960900","cep":"25193","endereco":"647 Miller Drive Suite 063\nWest Maria, CO 27087","mae":"Shannon","pai":"Matthew","responsavel":"Jennifer Anderson","observacoes":"Total commercial however wrong whole although than. Foot along along. Good war security call.\nDoctor service brother on study catch. Option actually doctor official conference develop blue."}
# {"id":29,"nome":"Michael Hendricks","nascimento":"1946-02-26","idade":77,"naturalidade":"North Jenniferview","nacionalidade":"Mongolia","sexo":"Feminino","cor":"DarkGreen","estadocivil":"Viúvo(a)","profissao":"Database administrator","telefone1":"+1-661-791-6603x945","telefone2":"7006252762","email1":"sandrabrown@example.org","email2":"stokesbrandi@example.com","cpf":"75877732961","rg":"437193704","rg_emissor":"IFP","cns":"138641768854476","cep":"28142","endereco":"Unit 6513 Box 7272\nDPO AE 30778","mae":"Madison","pai":"Anthony","responsavel":"Denise Anderson","observacoes":"Six poor first. Doctor lot operation hard general beautiful.\nImpact apply assume answer story network simply. Couple start avoid three consumer."}
# {"id":30,"nome":"Jason Simon","nascimento":"1949-04-01","idade":74,"naturalidade":"West Josetown","nacionalidade":"Hong Kong","sexo":"Masculino","cor":"DarkOliveGreen","estadocivil":"Divorciado(a)","profissao":"Translator","telefone1":"+1-804-973-6503","telefone2":"001-940-315-5248x73519","email1":"amber65@example.com","email2":"dmccormick@example.org","cpf":"85613178282","rg":"394710782","rg_emissor":"PF","cns":"316589944438630","cep":"49329","endereco":"7589 Lambert Avenue Suite 953\nBullockton, FM 30875","mae":"Heidi","pai":"Ernest","responsavel":"Kathryn Keller","observacoes":"Matter read song across for. Whatever evidence anyone enjoy project shake despite within. Would customer wall way government contain.\nOnto many Mr fine daughter her."}
# {"id":31,"nome":"Jack Adams","nascimento":"1977-07-07","idade":46,"naturalidade":"Traciehaven","nacionalidade":"Vietnam","sexo":"Feminino","cor":"Silver","estadocivil":"Viúvo(a)","profissao":"Medical laboratory scientific officer","telefone1":"850.444.4830x589","telefone2":"324-627-5535","email1":"nicolelynch@example.net","email2":"gjohnson@example.net","cpf":"30990145602","rg":"674494882","rg_emissor":"PF","cns":"581169296716288","cep":"30606","endereco":"4688 Robert Spurs Apt. 298\nJohnchester, MD 27195","mae":"Stephanie","pai":"John","responsavel":"David Carter","observacoes":"Student production Mr speak poor possible.\nLater hour table rock gas nice. Near road play mission grow car."}
# {"id":32,"nome":"Elizabeth Garrett","nascimento":"1970-05-17","idade":53,"naturalidade":"Lake Wyatt","nacionalidade":"Maldives","sexo":"Masculino","cor":"OldLace","estadocivil":"Casado(a)","profissao":"Advertising art director","telefone1":"(344)457-7222x15487","telefone2":"219-662-1827","email1":"daniel93@example.net","email2":"travisrodriguez@example.net","cpf":"70102905494","rg":"372901203","rg_emissor":"SSP","cns":"770187606195896","cep":"71922","endereco":"19350 Lamb Turnpike\nEast Cesar, MP 50861","mae":"Brooke","pai":"Thomas","responsavel":"Barbara Wood","observacoes":"Radio short big east. None choice guy discover. Later spring policy team address almost such.\nGas ten onto break car."}
# {"id":33,"nome":"Douglas Jackson","nascimento":"1949-07-16","idade":74,"naturalidade":"South Christian","nacionalidade":"Bermuda","sexo":"Masculino","cor":"DarkSlateBlue","estadocivil":"Divorciado(a)","profissao":"Technical sales engineer","telefone1":"785.344.2879x18097","telefone2":"(307)228-1704","email1":"colliertara@example.org","email2":"dalton44@example.net","cpf":"62429718631","rg":"941446657","rg_emissor":"IFP","cns":"782493820797835","cep":"36629","endereco":"00453 Kimberly Prairie Apt. 076\nNorth Daniel, ID 21924","mae":"Amanda","pai":"Ronald","responsavel":"Jessica Garcia","observacoes":"Feel author head own. Article be arrive hot science science."}
# {"id":34,"nome":"Carol Solomon","nascimento":"1944-04-25","idade":79,"naturalidade":"East Elizabethstad","nacionalidade":"Saint Lucia","sexo":"Masculino","cor":"DodgerBlue","estadocivil":"Viúvo(a)","profissao":"Hydrogeologist","telefone1":"(294)349-3725","telefone2":"989-701-3516x03559","email1":"marshronald@example.org","email2":"bgallagher@example.com","cpf":"49025577646","rg":"987370012","rg_emissor":"PF","cns":"175401883992901","cep":"13382","endereco":"788 Cynthia Alley Suite 968\nNorth Ashley, SC 18774","mae":"Brianna","pai":"Larry","responsavel":"Ryan Bishop","observacoes":"Yourself field by increase son player school. Away attack mean central finally later hit team. Blood card deep must.\nWith blue bar goal trip. Watch operation star threat near check low."}
# {"id":35,"nome":"Christopher Reilly","nascimento":"2005-08-23","idade":18,"naturalidade":"North Barbaratown","nacionalidade":"Holy See (Vatican City State)","sexo":"Masculino","cor":"Moccasin","estadocivil":"Viúvo(a)","profissao":"Mechanical engineer","telefone1":"949.491.4910x622","telefone2":"(833)218-4031","email1":"krausejoseph@example.com","email2":"mbrown@example.org","cpf":"78969940045","rg":"670808858","rg_emissor":"PF","cns":"702727072044896","cep":"60791","endereco":"Unit 2402 Box 4106\nDPO AE 68926","mae":"Anita","pai":"Connor","responsavel":"Chase Taylor","observacoes":"Reality sometimes now while every region receive wonder. Better over wish low be. Road happen great miss rule. Value market fire.\nCity artist amount because Mr however."}
# {"id":36,"nome":"Catherine Becker","nascimento":"1951-09-04","idade":72,"naturalidade":"North Richardhaven","nacionalidade":"Palau","sexo":"Masculino","cor":"LightPink","estadocivil":"Viúvo(a)","profissao":"Teacher, early years/pre","telefone1":"(654)857-9919x294","telefone2":"+1-531-206-1834x623","email1":"meganramsey@example.net","email2":"ichapman@example.net","cpf":"82160242168","rg":"674382468","rg_emissor":"PF","cns":"477227633500311","cep":"68200","endereco":"0021 Susan Light\nNew Johnport, VT 59404","mae":"Courtney","pai":"Daniel","responsavel":"Gary Solomon","observacoes":"Without effect blue watch behavior even. Case despite college analysis stock hospital. Threat lead strong three. Young trade near child glass style statement."}
# {"id":37,"nome":"Cynthia Griffin DDS","nascimento":"2000-07-16","idade":23,"naturalidade":"Port Kayla","nacionalidade":"Faroe Islands","sexo":"Masculino","cor":"Aqua","estadocivil":"Solteiro(a)","profissao":"Conservation officer, nature","telefone1":"(409)513-6194x615","telefone2":"+1-523-880-0474x812","email1":"hartcathy@example.com","email2":"perkinsapril@example.com","cpf":"32728111007","rg":"471319336","rg_emissor":"DETRAN","cns":"569771646889021","cep":"95701","endereco":"832 Cole Junction\nMontgomeryhaven, PW 01815","mae":"Kathy","pai":"Taylor","responsavel":"Kimberly Thomas","observacoes":"Compare teacher campaign beyond more. Capital three surface offer technology. Hair challenge note."}
# {"id":38,"nome":"Anthony Pace","nascimento":"1948-08-19","idade":75,"naturalidade":"Port Daniel","nacionalidade":"Guinea","sexo":"Feminino","cor":"Yellow","estadocivil":"Casado(a)","profissao":"Best boy","telefone1":"001-822-412-0058x930","telefone2":"+1-399-282-3863x87483","email1":"williamfreeman@example.org","email2":"hutchinsonandrew@example.org","cpf":"30429281546","rg":"329946922","rg_emissor":"DETRAN","cns":"561749222584679","cep":"69995","endereco":"55705 Riddle Estates\nJacobstad, DE 23784","mae":"Kelli","pai":"Edwin","responsavel":"Nicholas Wolfe","observacoes":"Check magazine read answer. Sometimes lot mouth no own read. Manager certain anyone specific.\nManagement pick loss PM. Go tend level whatever. Rather up assume."}
# {"id":39,"nome":"Logan Bowman","nascimento":"1951-02-22","idade":72,"naturalidade":"Mosesburgh","nacionalidade":"Burundi","sexo":"Masculino","cor":"WhiteSmoke","estadocivil":"Divorciado(a)","profissao":"Sport and exercise psychologist","telefone1":"001-382-439-5918x081","telefone2":"889.862.4979","email1":"dstephenson@example.com","email2":"grayaaron@example.net","cpf":"58383137254","rg":"683776339","rg_emissor":"IFP","cns":"775685966013189","cep":"43719","endereco":"0198 Crystal Common Suite 784\nObrienhaven, WV 05350","mae":"Jasmine","pai":"Christopher","responsavel":"Ryan Zimmerman","observacoes":"Yard key check approach miss home way. Change garden manager training structure society meeting. Everybody data week."}
# {"id":40,"nome":"Nicholas Harris","nascimento":"1963-10-21","idade":60,"naturalidade":"Jenkinsbury","nacionalidade":"Egypt","sexo":"Feminino","cor":"MediumSeaGreen","estadocivil":"Viúvo(a)","profissao":"Barrister's clerk","telefone1":"(956)825-3073","telefone2":"(828)507-9722","email1":"jessicalopez@example.com","email2":"joseph53@example.org","cpf":"34831260430","rg":"473168459","rg_emissor":"DETRAN","cns":"341912125161921","cep":"08228","endereco":"573 Sylvia Inlet Apt. 990\nJosestad, NJ 62537","mae":"Veronica","pai":"Richard","responsavel":"Brendan Torres","observacoes":"Decade you way through. Across court other under indicate here. Idea there answer.\nAuthority purpose that machine his. Father attorney response especially thing. Chair teacher my woman."}
# {"id":41,"nome":"Timothy Russell","nascimento":"1992-12-14","idade":30,"naturalidade":"South Anthonyland","nacionalidade":"Bermuda","sexo":"Feminino","cor":"DarkGray","estadocivil":"Casado(a)","profissao":"Electrical engineer","telefone1":"+1-228-936-3948x2762","telefone2":"+1-325-785-2083x333","email1":"angela00@example.net","email2":"mccarthykimberly@example.com","cpf":"81434058058","rg":"162359404","rg_emissor":"PF","cns":"370538427355757","cep":"74225","endereco":"543 Kristin Locks\nDevinmouth, NH 30413","mae":"Angela","pai":"Michael","responsavel":"Martha Sellers","observacoes":"Responsibility investment any play. Week back street lot bank fight two.\nGroup president sister guess. Speech painting response much reflect."}
# {"id":42,"nome":"Anthony Roberts","nascimento":"1991-03-29","idade":32,"naturalidade":"Brandyside","nacionalidade":"Turkmenistan","sexo":"Masculino","cor":"MediumPurple","estadocivil":"Casado(a)","profissao":"Therapeutic radiographer","telefone1":"336-608-0527","telefone2":"343-302-0246","email1":"michael18@example.net","email2":"williamslatasha@example.net","cpf":"26208586561","rg":"882199594","rg_emissor":"IFP","cns":"482499224959273","cep":"98379","endereco":"USNS Rodriguez\nFPO AA 92235","mae":"Megan","pai":"Benjamin","responsavel":"Heidi Franklin","observacoes":"Increase debate station bad pay any. Generation poor white win relationship.\nLight never you weight live compare. Vote later play knowledge positive. Reveal all evening enough."}
# {"id":43,"nome":"Sarah Fischer","nascimento":"2000-09-14","idade":23,"naturalidade":"Finleyland","nacionalidade":"United States Minor Outlying Islands","sexo":"Masculino","cor":"Silver","estadocivil":"Casado(a)","profissao":"Fitness centre manager","telefone1":"348.842.8722","telefone2":"308-290-9812x60243","email1":"billy62@example.net","email2":"tcampbell@example.org","cpf":"48020180945","rg":"379039161","rg_emissor":"SSP","cns":"118435982615343","cep":"32477","endereco":"23430 Jason Underpass Apt. 132\nWest Mikaylachester, CT 28905","mae":"Amy","pai":"Joseph","responsavel":"Janice Sullivan","observacoes":"While laugh once store. Management important blue benefit.\nDecision position sure natural hand. Relationship share tough reveal buy none. Political letter could push attorney."}
# {"id":44,"nome":"Frank Ramirez","nascimento":"1973-01-19","idade":50,"naturalidade":"West Martinland","nacionalidade":"Cyprus","sexo":"Masculino","cor":"Violet","estadocivil":"Divorciado(a)","profissao":"Adult nurse","telefone1":"(858)344-9673","telefone2":"333.950.0352x894","email1":"bellsarah@example.org","email2":"mscott@example.net","cpf":"70897608832","rg":"417783908","rg_emissor":"SSP","cns":"289642904919235","cep":"45143","endereco":"41532 Derrick Highway Suite 884\nEast Raymondville, IA 26206","mae":"Ellen","pai":"Jason","responsavel":"Michael Frederick","observacoes":"Significant situation down wall use truth.\nFinally face clearly together assume product. Road happy sit everybody though improve. Particularly history staff board which same think child."}
# {"id":45,"nome":"Erin Bradley","nascimento":"1988-01-17","idade":35,"naturalidade":"Guerrastad","nacionalidade":"Mauritania","sexo":"Masculino","cor":"Ivory","estadocivil":"Solteiro(a)","profissao":"Mechanical engineer","telefone1":"001-278-483-5175x4854","telefone2":"001-874-538-9730x610","email1":"smithkevin@example.com","email2":"jeffreyknapp@example.org","cpf":"68988836887","rg":"824105198","rg_emissor":"DETRAN","cns":"676587755607745","cep":"37802","endereco":"21488 Fernandez Streets Suite 794\nSouth Loriburgh, NH 52799","mae":"Sheila","pai":"Angel","responsavel":"Kevin Joseph","observacoes":"Morning five painting do culture their for. Employee deep high."}
# {"id":46,"nome":"Miss Brenda Sanchez","nascimento":"1944-06-25","idade":79,"naturalidade":"Alexandrabury","nacionalidade":"Gambia","sexo":"Masculino","cor":"BlanchedAlmond","estadocivil":"Divorciado(a)","profissao":"Research scientist (maths)","telefone1":"301.979.7523x238","telefone2":"219-253-0706x9350","email1":"oscar83@example.com","email2":"xsmith@example.com","cpf":"53678555010","rg":"650602304","rg_emissor":"DETRAN","cns":"234565340019258","cep":"24055","endereco":"666 Barnett Bypass Apt. 469\nEast Scottview, LA 25813","mae":"Jennifer","pai":"Devon","responsavel":"Jennifer Green","observacoes":"His teach dark defense school financial study. Marriage Mr realize fly about next voice. Down common ten prevent good thing notice.\nActivity sort provide institution capital sign these physical."}
# {"id":47,"nome":"Cathy Howell","nascimento":"1968-05-18","idade":55,"naturalidade":"West Cynthia","nacionalidade":"Cocos (Keeling) Islands","sexo":"Masculino","cor":"Purple","estadocivil":"Viúvo(a)","profissao":"Clinical biochemist","telefone1":"9946859997","telefone2":"581.265.0684","email1":"kswanson@example.net","email2":"sgreen@example.com","cpf":"41562713957","rg":"225427970","rg_emissor":"DETRAN","cns":"983561430893040","cep":"88448","endereco":"47955 Kristy Village Suite 219\nWest Alexanderhaven, NJ 30702","mae":"Christina","pai":"Jesse","responsavel":"Julia Frazier","observacoes":"Clear where old weight because.\nEnvironment on trial really. Yet collection during yes everyone apply ready finish.\nOperation pass attention catch town. Education another know."}
# {"id":48,"nome":"Denise Rodriguez","nascimento":"1983-12-01","idade":39,"naturalidade":"Flowerschester","nacionalidade":"Marshall Islands","sexo":"Feminino","cor":"Gold","estadocivil":"Divorciado(a)","profissao":"Forest/woodland manager","telefone1":"(690)760-5464","telefone2":"282-693-1853","email1":"lwilliams@example.org","email2":"michaelmartinez@example.net","cpf":"88600412036","rg":"336443207","rg_emissor":"IFP","cns":"458726892359306","cep":"25975","endereco":"6927 Latoya Valley Apt. 662\nNew Derek, KS 91940","mae":"Andrea","pai":"David","responsavel":"Robert Mccoy","observacoes":"Teacher their many drop. Contain Democrat weight identify understand specific. Nation arrive myself effort watch. True realize red third nation station."}
# {"id":49,"nome":"Aaron Murphy","nascimento":"2001-06-19","idade":22,"naturalidade":"Crystalstad","nacionalidade":"Mauritania","sexo":"Feminino","cor":"FireBrick","estadocivil":"Solteiro(a)","profissao":"Armed forces operational officer","telefone1":"607-447-0829x99517","telefone2":"001-951-921-5698","email1":"smithann@example.net","email2":"gstewart@example.net","cpf":"32382674039","rg":"960264571","rg_emissor":"SSP","cns":"869823810100891","cep":"71783","endereco":"1632 Thomas Pass\nFrancisfort, FM 68729","mae":"Jessica","pai":"Brent","responsavel":"Dr. Jorge Wilson","observacoes":"Cause open perhaps. Father this language yourself blood threat there not.\nAgo before serious yeah born especially. Suffer size relate front best sell statement."}
# {"id":50,"nome":"Samantha Taylor","nascimento":"1966-03-25","idade":57,"naturalidade":"Kylemouth","nacionalidade":"Maldives","sexo":"Feminino","cor":"Violet","estadocivil":"Viúvo(a)","profissao":"Field trials officer","telefone1":"+1-507-902-3700x945","telefone2":"357-826-6980x7687","email1":"walshnancy@example.com","email2":"mclaughlinstacy@example.com","cpf":"23603667219","rg":"581789739","rg_emissor":"IFP","cns":"750988117821711","cep":"16878","endereco":"4755 Moody Way Suite 920\nOrtizview, DC 76168","mae":"Lindsay","pai":"Robert","responsavel":"Rachel Flores","observacoes":"Country left defense strong by. Prevent party letter shoulder military. Organization ball wide figure.\nThroughout focus focus air wrong ball. Add cover unit six no figure instead."}
# {"id":51,"nome":"Alex Lawson","nascimento":"2003-09-25","idade":20,"naturalidade":"Lisaport","nacionalidade":"Syrian Arab Republic","sexo":"Feminino","cor":"MediumAquaMarine","estadocivil":"Viúvo(a)","profissao":"IT trainer","telefone1":"+1-281-541-1754x771","telefone2":"+1-265-536-1666","email1":"kscott@example.org","email2":"eparker@example.net","cpf":"18696379448","rg":"902989850","rg_emissor":"DETRAN","cns":"511606135673307","cep":"79920","endereco":"02560 Gary Gateway Apt. 581\nTuckerport, UT 95883","mae":"Kristi","pai":"Travis","responsavel":"Joshua Morris","observacoes":"Home personal never two. Popular provide accept face scene million.\nCharacter game certainly well build.\nFight gas southern."}
# {"id":52,"nome":"Megan Baker DDS","nascimento":"1959-09-30","idade":64,"naturalidade":"New Maryburgh","nacionalidade":"Sudan","sexo":"Feminino","cor":"DarkRed","estadocivil":"Solteiro(a)","profissao":"Production assistant, television","telefone1":"9326214078","telefone2":"001-556-385-9391x11559","email1":"qstone@example.com","email2":"dmathews@example.com","cpf":"17549744807","rg":"131902392","rg_emissor":"PF","cns":"866118186609508","cep":"68311","endereco":"241 Antonio Junctions Suite 077\nSalasport, CA 52895","mae":"Lisa","pai":"Michael","responsavel":"Amanda Suarez","observacoes":"Question deal those point. Individual laugh worker hotel technology matter board.\nEnd mention item fall without. Give without design growth."}
# {"id":53,"nome":"Stephanie Landry","nascimento":"1966-08-14","idade":57,"naturalidade":"South Michelle","nacionalidade":"Ireland","sexo":"Masculino","cor":"RoyalBlue","estadocivil":"Divorciado(a)","profissao":"Retail manager","telefone1":"(828)941-1518x652","telefone2":"+1-597-706-9799x559","email1":"benjaminking@example.net","email2":"ivansolomon@example.com","cpf":"17173599492","rg":"678368374","rg_emissor":"IFP","cns":"402370522110391","cep":"35806","endereco":"393 Harris Shoals Apt. 161\nNew April, MN 98214","mae":"Brooke","pai":"Nathaniel","responsavel":"Stephanie Ortiz","observacoes":"Each long enter two nice sort. With board consumer gas region. Indeed task hold describe go determine."}
# {"id":54,"nome":"Samantha Velasquez","nascimento":"1950-10-29","idade":73,"naturalidade":"Stevenmouth","nacionalidade":"Tunisia","sexo":"Masculino","cor":"Orange","estadocivil":"Solteiro(a)","profissao":"Museum/gallery conservator","telefone1":"215-273-5846x270","telefone2":"718.850.8605x5848","email1":"ryan24@example.org","email2":"kim54@example.com","cpf":"43383678875","rg":"399963282","rg_emissor":"PF","cns":"710110874510700","cep":"39711","endereco":"PSC 4348, Box 7141\nAPO AE 12121","mae":"Heather","pai":"David","responsavel":"Brett Tucker","observacoes":"Rise customer word book care car current environmental. Parent soldier opportunity middle along. Process everyone laugh federal buy newspaper red. Business buy local under."}
# {"id":55,"nome":"Darren Serrano","nascimento":"1994-03-13","idade":29,"naturalidade":"Newmantown","nacionalidade":"Cayman Islands","sexo":"Masculino","cor":"BurlyWood","estadocivil":"Viúvo(a)","profissao":"Public relations officer","telefone1":"580.431.1510","telefone2":"616-321-8685x382","email1":"curtisgregory@example.org","email2":"harrisjulian@example.org","cpf":"56665969126","rg":"570539023","rg_emissor":"IFP","cns":"884464529077516","cep":"75462","endereco":"633 Matthew Courts\nKimberlytown, MI 25900","mae":"Doris","pai":"Steven","responsavel":"Thomas Lang","observacoes":"Animal job a always purpose popular population. Congress wife nature especially lead. Our western I major accept affect my.\nSo single push enough still. Fight follow central court since early."}
# {"id":56,"nome":"Michael Buckley","nascimento":"1933-01-28","idade":90,"naturalidade":"Priceport","nacionalidade":"Albania","sexo":"Masculino","cor":"IndianRed","estadocivil":"Divorciado(a)","profissao":"Surveyor, building control","telefone1":"905-571-4877x0728","telefone2":"+1-948-655-7223","email1":"ymoore@example.net","email2":"kbentley@example.org","cpf":"39879623619","rg":"675359978","rg_emissor":"IFP","cns":"119786699894019","cep":"13005","endereco":"436 Thomas Mall Apt. 364\nBauerfurt, WV 36566","mae":"Sheila","pai":"Patrick","responsavel":"Tabitha Holloway","observacoes":"Leave church total financial hospital. Item sell south. Health way above do region. Huge if air her."}
# {"id":57,"nome":"Kimberly Scott","nascimento":"1956-06-12","idade":67,"naturalidade":"Reyesstad","nacionalidade":"North Macedonia","sexo":"Feminino","cor":"LightBlue","estadocivil":"Divorciado(a)","profissao":"Psychologist, forensic","telefone1":"821.225.5647","telefone2":"(771)582-7292x87199","email1":"jonathan95@example.net","email2":"gmcdowell@example.net","cpf":"23181841734","rg":"305323536","rg_emissor":"SSP","cns":"725714999287234","cep":"02438","endereco":"6921 Dickerson Dale Suite 360\nBradleyberg, RI 10265","mae":"Margaret","pai":"Christopher","responsavel":"Michael Myers","observacoes":"Sign sort what police. Others growth central event.\nCity enough bad.\nInto war carry first their there. Remember work best color project although management. Produce age good."}
# {"id":58,"nome":"Lori Parks","nascimento":"2003-10-19","idade":20,"naturalidade":"Thomasmouth","nacionalidade":"Martinique","sexo":"Masculino","cor":"Yellow","estadocivil":"Divorciado(a)","profissao":"Cabin crew","telefone1":"001-502-808-0007x5402","telefone2":"489-712-8469x1447","email1":"nelsonjoseph@example.com","email2":"roberta15@example.org","cpf":"51709697148","rg":"128786786","rg_emissor":"PF","cns":"660484354538106","cep":"61822","endereco":"156 Matthew Knoll Suite 223\nChristophershire, DC 95570","mae":"Rebecca","pai":"Spencer","responsavel":"Mr. Michael Schmidt","observacoes":"Stay according change attack. Read government born task word between president.\nFine last ok look particularly. Go American although how once gun. Put tonight next how financial natural understand."}
# {"id":59,"nome":"Crystal Smith","nascimento":"1933-01-05","idade":90,"naturalidade":"Taylormouth","nacionalidade":"Serbia","sexo":"Feminino","cor":"PapayaWhip","estadocivil":"Viúvo(a)","profissao":"Production assistant, radio","telefone1":"(714)655-8907x89499","telefone2":"353.297.2020","email1":"xdavis@example.com","email2":"denisewatts@example.com","cpf":"30114331717","rg":"114618272","rg_emissor":"PF","cns":"959570777254243","cep":"48250","endereco":"7189 Baker Key\nNorth Thomasfurt, KS 28014","mae":"Kimberly","pai":"Zachary","responsavel":"Kevin Leonard","observacoes":"Minute want everything bed lot. Catch imagine professor line."}
# {"id":60,"nome":"Patricia Woodward","nascimento":"1972-11-22","idade":51,"naturalidade":"South Andrew","nacionalidade":"South Georgia and the South Sandwich Islands","sexo":"Feminino","cor":"CadetBlue","estadocivil":"Casado(a)","profissao":"Advertising account planner","telefone1":"560-286-2635x56612","telefone2":"867-275-8229x259","email1":"cookpatricia@example.org","email2":"utanner@example.net","cpf":"29261320913","rg":"602603586","rg_emissor":"DETRAN","cns":"789702885388800","cep":"76180","endereco":"PSC 1401, Box 1310\nAPO AP 28284","mae":"Alicia","pai":"Christopher","responsavel":"Kari Aguilar","observacoes":"Together a price speech how. Trouble start open heavy house can program more.\nWould recognize little TV a oil. Likely board morning message thank media bag movement."}
# {"id":61,"nome":"Miss Brittany Hall","nascimento":"1933-05-05","idade":90,"naturalidade":"Wrightfort","nacionalidade":"Estonia","sexo":"Masculino","cor":"CadetBlue","estadocivil":"Solteiro(a)","profissao":"Bookseller","telefone1":"001-783-618-8979","telefone2":"001-856-316-1255x4330","email1":"nicholas27@example.net","email2":"carla13@example.org","cpf":"79347315828","rg":"397915742","rg_emissor":"DETRAN","cns":"945966560539460","cep":"32493","endereco":"0574 White Plaza Apt. 062\nLynnport, MT 43060","mae":"Charlene","pai":"Ian","responsavel":"Sara Lopez","observacoes":"Major international mission build couple. Condition natural news Democrat field until side rock. Become task firm worker sport plant."}
# {"id":62,"nome":"Kimberly Black","nascimento":"1993-12-04","idade":29,"naturalidade":"Amandashire","nacionalidade":"Germany","sexo":"Masculino","cor":"BlueViolet","estadocivil":"Viúvo(a)","profissao":"Youth worker","telefone1":"001-382-690-2500","telefone2":"001-360-861-4199x02758","email1":"lindakent@example.net","email2":"chelseaolson@example.org","cpf":"26730720398","rg":"754128676","rg_emissor":"SSP","cns":"950724384831055","cep":"28202","endereco":"17876 Smith Curve Apt. 786\nEast Amandafort, MO 98809","mae":"Jennifer","pai":"Michael","responsavel":"Jennifer Archer","observacoes":"Lot concern media trade. Congress protect anyone wife heart husband fall. Weight practice television walk."}
# {"id":63,"nome":"Mr. Curtis Davis","nascimento":"1946-04-25","idade":77,"naturalidade":"West Kimberlyview","nacionalidade":"Barbados","sexo":"Masculino","cor":"CornflowerBlue","estadocivil":"Casado(a)","profissao":"Designer, television/film set","telefone1":"8859883316","telefone2":"510.469.1274","email1":"krista48@example.com","email2":"benjamin38@example.net","cpf":"62358686561","rg":"643270964","rg_emissor":"PF","cns":"441497910053791","cep":"04671","endereco":"03146 Jones Estates\nColemanfurt, PA 15581","mae":"Dawn","pai":"Kevin","responsavel":"Lindsay Jennings","observacoes":"Add heavy expert style leave life section.\nRise stop population itself. Second right both rule offer seek activity."}
# {"id":64,"nome":"Tammy Carter","nascimento":"1979-02-16","idade":44,"naturalidade":"Lake Margaretbury","nacionalidade":"Egypt","sexo":"Masculino","cor":"LemonChiffon","estadocivil":"Casado(a)","profissao":"Production engineer","telefone1":"(456)322-2482","telefone2":"(371)631-2198x44331","email1":"vrobinson@example.com","email2":"xwebster@example.com","cpf":"64418960564","rg":"609066774","rg_emissor":"PF","cns":"680224810098270","cep":"13330","endereco":"497 Jones Ways Apt. 329\nEast Jameston, MI 33767","mae":"Jessica","pai":"Jacob","responsavel":"Deborah Gould","observacoes":"What reflect draw realize also beat research. Argue beyond hour suddenly range. Forget statement world mean mission yourself teach."}
# ...
# {"id":180,"nome":"Emily Rowland","nascimento":"1975-02-03","idade":48,"naturalidade":"North Kevinborough","nacionalidade":"Qatar","sexo":"Feminino","cor":"MintCream","estadocivil":"Casado(a)","profissao":"Engineer, land","telefone1":"377.895.2796","telefone2":"669.531.9951","email1":"mprice@example.org","email2":"christinediaz@example.com","cpf":"82242098766","rg":"403742153","rg_emissor":"PF","cns":"539257663952033","cep":"57116","endereco":"90825 Snyder Green Apt. 487\nSouth Kenneth, FM 32894","mae":"Kari","pai":"Robert","responsavel":"Thomas Yang","observacoes":"National science condition its. Appear others color trouble quite care. Write pick society improve.\nResponsibility society watch pretty bed hit. North whether relationship treat find."}
# {"id":181,"nome":"Kelly Wheeler DDS","nascimento":"1994-12-27","idade":28,"naturalidade":"Lake James","nacionalidade":"Morocco","sexo":"Masculino","cor":"Cornsilk","estadocivil":"Solteiro(a)","profissao":"Education officer, environmental","telefone1":"(508)967-7864","telefone2":"001-547-542-6636","email1":"matthewroach@example.net","email2":"paulgonzales@example.org","cpf":"99581282991","rg":"518288811","rg_emissor":"SSP","cns":"374401411350687","cep":"61277","endereco":"04624 Smith Shoals Apt. 151\nWarrenfurt, AK 51789","mae":"Theresa","pai":"David","responsavel":"Yesenia Goodwin","observacoes":"Who science group into style less. Consumer none view.\nManagement such laugh today long action. Individual recently respond hold only. Stuff become project computer bring."}
# {"id":182,"nome":"Ryan Garza","nascimento":"1977-06-13","idade":46,"naturalidade":"Julieland","nacionalidade":"American Samoa","sexo":"Feminino","cor":"Blue","estadocivil":"Casado(a)","profissao":"Statistician","telefone1":"(230)318-2271","telefone2":"803-937-8490","email1":"armstrongmichelle@example.com","email2":"emilyoconnor@example.org","cpf":"30399000887","rg":"827407442","rg_emissor":"SSP","cns":"114098365408309","cep":"56559","endereco":"PSC 6898, Box 6084\nAPO AP 96171","mae":"Briana","pai":"Tom","responsavel":"Rebecca Davis","observacoes":"Or short hold office fish. Us page become action manager skin."}
# {"id":183,"nome":"Jennifer Snyder","nascimento":"1978-10-24","idade":45,"naturalidade":"West Danielle","nacionalidade":"Bahamas","sexo":"Masculino","cor":"LightSeaGreen","estadocivil":"Solteiro(a)","profissao":"Administrator","telefone1":"4098347638","telefone2":"827.480.4741x174","email1":"taylor85@example.net","email2":"austin15@example.net","cpf":"44455307134","rg":"405844635","rg_emissor":"PF","cns":"290171941673398","cep":"03795","endereco":"72284 Juan Well\nNew Catherineberg, ND 28989","mae":"Cathy","pai":"Ryan","responsavel":"Jennifer Salazar","observacoes":"Above general identify improve room thus miss. Executive spend year.\nCareer chance order trial enough environment."}
# {"id":184,"nome":"Tammy Diaz","nascimento":"1997-04-12","idade":26,"naturalidade":"Port Donald","nacionalidade":"Kenya","sexo":"Feminino","cor":"Wheat","estadocivil":"Casado(a)","profissao":"Archaeologist","telefone1":"478-524-0389","telefone2":"(781)691-4954x85985","email1":"ymartinez@example.org","email2":"carpentermichael@example.net","cpf":"19528718372","rg":"318467811","rg_emissor":"IFP","cns":"954568035294240","cep":"17015","endereco":"2807 Swanson Fords\nHernandezbury, WV 38925","mae":"Gabrielle","pai":"Michael","responsavel":"Carol Hobbs","observacoes":"Front particularly hair strong scene woman. This alone him human he sport.\nStudent gun indeed quickly ready. Certain consumer finally point tonight write movie."}
# {"id":185,"nome":"Emily Weaver","nascimento":"1971-10-21","idade":52,"naturalidade":"New Keithchester","nacionalidade":"Israel","sexo":"Masculino","cor":"Lavender","estadocivil":"Casado(a)","profissao":"Professor Emeritus","telefone1":"(445)697-1554","telefone2":"001-912-691-1103x115","email1":"jonescharles@example.net","email2":"hannahcisneros@example.com","cpf":"17680241322","rg":"852906673","rg_emissor":"SSP","cns":"120005848400290","cep":"16212","endereco":"6066 Keller Mall\nAngelachester, WV 63130","mae":"Cassandra","pai":"Ryan","responsavel":"Katherine Martinez","observacoes":"Memory board entire store energy air buy people. Main list improve responsibility toward. Tax focus occur behind."}
# {"id":186,"nome":"Paige Montoya","nascimento":"1996-07-12","idade":27,"naturalidade":"Jessicaport","nacionalidade":"Saint Helena","sexo":"Masculino","cor":"CornflowerBlue","estadocivil":"Casado(a)","profissao":"Veterinary surgeon","telefone1":"381-350-6372x42698","telefone2":"+1-686-777-5287x84434","email1":"munozrachel@example.org","email2":"carlrichardson@example.net","cpf":"38713997308","rg":"563801302","rg_emissor":"DETRAN","cns":"471041589175620","cep":"95919","endereco":"05087 Watson Mountains\nNorth Melissafurt, FL 51262","mae":"Brittany","pai":"Timothy","responsavel":"Elizabeth Singh","observacoes":"Century yeah dark well more behavior know. Lay perhaps live yourself voice.\nControl whom morning education movement career lay. Research reduce often set language. Two threat huge walk."}
# {"id":187,"nome":"John Curtis","nascimento":"1959-11-08","idade":64,"naturalidade":"East Ericaport","nacionalidade":"Cuba","sexo":"Feminino","cor":"Purple","estadocivil":"Viúvo(a)","profissao":"Agricultural consultant","telefone1":"001-988-411-4857x705","telefone2":"(523)953-3664x5993","email1":"amyphillips@example.com","email2":"lreyes@example.org","cpf":"10239309399","rg":"879000886","rg_emissor":"IFP","cns":"193394236160453","cep":"06010","endereco":"451 Brown Mountain\nRogerstown, OK 28928","mae":"Amanda","pai":"Stanley","responsavel":"Adam Thompson","observacoes":"Movie operation his. Indicate serve successful recent other common center. Under down continue oil family get. Key truth structure sport father technology then."}
# {"id":188,"nome":"Jason Erickson","nascimento":"1949-01-07","idade":74,"naturalidade":"Browningshire","nacionalidade":"Israel","sexo":"Masculino","cor":"DarkBlue","estadocivil":"Viúvo(a)","profissao":"Marine scientist","telefone1":"001-531-835-2899x52262","telefone2":"259-701-7884x03285","email1":"rodriguezstephanie@example.com","email2":"seanterrell@example.net","cpf":"55765512399","rg":"873933025","rg_emissor":"PF","cns":"362963514271364","cep":"09593","endereco":"149 Davis Center Suite 935\nPort Sarah, FL 10863","mae":"Leslie","pai":"James","responsavel":"Brian Clark","observacoes":"Hospital sister many see. Name bill rather catch stop wide. Catch laugh more from."}
# {"id":189,"nome":"Stephen Goodman","nascimento":"1964-04-04","idade":59,"naturalidade":"Kimberlyfurt","nacionalidade":"Switzerland","sexo":"Masculino","cor":"LawnGreen","estadocivil":"Divorciado(a)","profissao":"Horticultural therapist","telefone1":"843-982-0789x958","telefone2":"903.613.1621","email1":"tsanchez@example.com","email2":"nancy28@example.org","cpf":"85617656505","rg":"224462836","rg_emissor":"PF","cns":"875675575724624","cep":"93079","endereco":"302 Turner Square Suite 910\nMichelleshire, NY 51194","mae":"Kathleen","pai":"Larry","responsavel":"Antonio Jordan","observacoes":"Around any finally standard. Likely manage lot Mr term.\nProperty need well success purpose movie policy. Serious senior fight avoid teach remain offer customer. Theory remain open research."}
# {"id":190,"nome":"Shannon Russell","nascimento":"1954-03-15","idade":69,"naturalidade":"East Crystalside","nacionalidade":"Anguilla","sexo":"Masculino","cor":"Blue","estadocivil":"Divorciado(a)","profissao":"Banker","telefone1":"286-534-4604","telefone2":"7652141952","email1":"ryan55@example.net","email2":"xrice@example.net","cpf":"25428212183","rg":"143110639","rg_emissor":"PF","cns":"433471296346673","cep":"03276","endereco":"0873 Johnson Station Suite 109\nSouth Rachelborough, MI 76491","mae":"Stacey","pai":"Dustin","responsavel":"Zachary Peterson","observacoes":"Line big stage activity. Near common make family individual. Design pull car body concern position event."}
# {"id":191,"nome":"Matthew Gonzalez","nascimento":"1951-02-13","idade":72,"naturalidade":"East Michael","nacionalidade":"Kiribati","sexo":"Masculino","cor":"MediumTurquoise","estadocivil":"Solteiro(a)","profissao":"Cabin crew","telefone1":"356.745.9832","telefone2":"3397736613","email1":"mary02@example.com","email2":"stephanie92@example.com","cpf":"13556332615","rg":"453299297","rg_emissor":"IFP","cns":"469392417753108","cep":"56924","endereco":"10782 Johnson Shore\nDavisbury, UT 18016","mae":"Lauren","pai":"Nicholas","responsavel":"Beth Blevins","observacoes":"Race experience large rate. Return wall stock stay.\nQuestion however debate until. Walk sit a nice wait hotel natural wall.\nThus mission well six smile local. Eight interesting able future food."}
# {"id":192,"nome":"Dylan West","nascimento":"1952-05-27","idade":71,"naturalidade":"Craigside","nacionalidade":"United Arab Emirates","sexo":"Masculino","cor":"AliceBlue","estadocivil":"Casado(a)","profissao":"Curator","telefone1":"(424)404-5454x38446","telefone2":"001-686-922-7076x309","email1":"annette36@example.com","email2":"tommy27@example.com","cpf":"98996623513","rg":"328939276","rg_emissor":"DETRAN","cns":"102295635186675","cep":"42711","endereco":"31916 Zachary Hills Apt. 510\nWillisfort, MP 38213","mae":"Jessica","pai":"Mitchell","responsavel":"Tracy Watts","observacoes":"Then those discover everyone left. Song information still central research action someone in. Environment future crime still form. Score move general board else do among."}
# {"id":193,"nome":"Melissa Knight","nascimento":"1940-06-15","idade":83,"naturalidade":"West Bethanyborough","nacionalidade":"Iran","sexo":"Feminino","cor":"DarkOliveGreen","estadocivil":"Viúvo(a)","profissao":"Primary school teacher","telefone1":"654.994.6003","telefone2":"+1-695-367-8937","email1":"debragordon@example.com","email2":"arthursnyder@example.org","cpf":"95935903841","rg":"353822175","rg_emissor":"DETRAN","cns":"505033396276411","cep":"38445","endereco":"2602 Daniel Landing Suite 805\nRiddleborough, VA 50618","mae":"Kimberly","pai":"Hector","responsavel":"Justin Andrews","observacoes":"Matter shoulder particularly. Born short real true heavy vote scene."}
# {"id":194,"nome":"Kevin Holmes","nascimento":"2005-08-23","idade":18,"naturalidade":"Wilsonview","nacionalidade":"Brazil","sexo":"Feminino","cor":"Tan","estadocivil":"Viúvo(a)","profissao":"Nurse, adult","telefone1":"+1-534-808-0813x99845","telefone2":"(513)907-4392","email1":"walterkelly@example.net","email2":"gmueller@example.net","cpf":"90783258744","rg":"123697914","rg_emissor":"PF","cns":"525941541476125","cep":"93638","endereco":"79471 Phillips Motorway Suite 068\nOrtizhaven, NH 30837","mae":"Deborah","pai":"Rodney","responsavel":"Mary Larsen","observacoes":"Phone yeah admit former. Decision hot reduce. Model what finally design what something company."}
# {"id":195,"nome":"Anthony Smith","nascimento":"1986-01-22","idade":37,"naturalidade":"Port Jeremy","nacionalidade":"Slovenia","sexo":"Masculino","cor":"SaddleBrown","estadocivil":"Casado(a)","profissao":"Hydrologist","telefone1":"001-777-479-8953x0966","telefone2":"646-380-7099x32998","email1":"cobbcarlos@example.org","email2":"laurenhooper@example.com","cpf":"13000782930","rg":"914876250","rg_emissor":"PF","cns":"426831484295365","cep":"13174","endereco":"97794 Williams Manor Apt. 431\nAcostaborough, NM 79854","mae":"Amber","pai":"Patrick","responsavel":"Nancy Cochran","observacoes":"Seat skin television finish environment move test always. Admit affect within itself difference true magazine.\nTeam spring quickly partner. Social sport order or quite."}
# {"id":196,"nome":"Stephen Clark","nascimento":"1976-06-03","idade":47,"naturalidade":"Allisonshire","nacionalidade":"Algeria","sexo":"Feminino","cor":"MediumSlateBlue","estadocivil":"Viúvo(a)","profissao":"Nurse, adult","telefone1":"+1-815-368-3779x67748","telefone2":"(827)484-2897x3868","email1":"molinamichael@example.net","email2":"carrienoble@example.com","cpf":"95103590134","rg":"977123995","rg_emissor":"SSP","cns":"365868252275377","cep":"46968","endereco":"3775 Samuel Fork Suite 010\nLauriestad, IA 82274","mae":"Grace","pai":"Micheal","responsavel":"Anthony Baker","observacoes":"Require wall do foot. Voice future difficult ask here play somebody physical. Modern high lay every I network."}
# {"id":197,"nome":"Alyssa Riddle","nascimento":"1955-11-11","idade":68,"naturalidade":"New Tashafurt","nacionalidade":"Yemen","sexo":"Masculino","cor":"DarkGray","estadocivil":"Divorciado(a)","profissao":"Homeopath","telefone1":"871.411.2919","telefone2":"(736)545-3967x51552","email1":"ydurham@example.com","email2":"davisjulie@example.com","cpf":"65074197867","rg":"443221847","rg_emissor":"PF","cns":"749108381684697","cep":"42906","endereco":"87485 Jessica Knolls\nNew Richard, MH 74617","mae":"Michelle","pai":"David","responsavel":"Alexandra Lewis","observacoes":"Scene total more everyone true. System concern others cost a catch personal.\nLead move some opportunity close ago course lose. Tv do over education operation official."}
# {"id":198,"nome":"Robert Salas","nascimento":"1985-10-15","idade":38,"naturalidade":"Michaelshire","nacionalidade":"Yemen","sexo":"Feminino","cor":"NavajoWhite","estadocivil":"Solteiro(a)","profissao":"Multimedia programmer","telefone1":"925-740-4306x7561","telefone2":"+1-445-561-6592x62314","email1":"alison52@example.com","email2":"ywalker@example.org","cpf":"27298072215","rg":"814797982","rg_emissor":"IFP","cns":"239362416743597","cep":"24275","endereco":"427 Gary Shore Apt. 822\nPort Julialand, OH 68679","mae":"Ellen","pai":"Michael","responsavel":"Katie Pierce","observacoes":"Family value go current. Stage particularly necessary course board.\nOutside town medical. All easy security alone eye. Seek can be organization."}
# {"id":199,"nome":"Emily Garrett","nascimento":"1995-05-01","idade":28,"naturalidade":"North Darren","nacionalidade":"Burundi","sexo":"Feminino","cor":"BurlyWood","estadocivil":"Solteiro(a)","profissao":"Scientist, water quality","telefone1":"+1-289-842-9404x1490","telefone2":"+1-308-973-5206x622","email1":"byrdmark@example.net","email2":"matthew97@example.net","cpf":"14591101584","rg":"474390076","rg_emissor":"IFP","cns":"702651054258348","cep":"54000","endereco":"279 Brian Port\nEmilymouth, CA 26388","mae":"Rebecca","pai":"Christopher","responsavel":"Charles Webb DVM","observacoes":"Leg example never everything so. Born degree do.\nFear hotel expert rule. How response discuss game he. Choose best of whom thousand there relationship. Think analysis feel."}
# {"id":200,"nome":"Robert Baker","nascimento":"1981-08-07","idade":42,"naturalidade":"Lake Michaelafurt","nacionalidade":"Italy","sexo":"Masculino","cor":"DarkGreen","estadocivil":"Casado(a)","profissao":"Building surveyor","telefone1":"+1-265-393-8136x0038","telefone2":"224-909-3304x52774","email1":"jenniferrivera@example.org","email2":"brianandrews@example.com","cpf":"20382706166","rg":"938672950","rg_emissor":"DETRAN","cns":"985100801153538","cep":"02355","endereco":"76268 Scott Islands Apt. 519\nSimpsonmouth, NY 96939","mae":"Patricia","pai":"Jeffrey","responsavel":"Joann Steele DDS","observacoes":"Nice here organization maintain mouth but follow site. Interest view born."}

# %%
# atualiza paciente

url = 'http://127.0.0.1:8000/agendasis/api/pacientes/'
headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access["rodolfo"]}'}
r = requests.get(url,headers=headers)
pacientes = json.loads(r.content)
fake = Faker()
data = {}
hoje =  datetime.now().date()
for i in range(10):
    paciente = random.choice(pacientes)
    url = f'http://127.0.0.1:8000/agendasis/api/pacientes/{paciente["id"]}/'
    headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access[random.choice(["rodolfo","moiseis"])]}'}
    nome=fake.name()
    nascimento=fake.date_of_birth(minimum_age=18, maximum_age=90)
    idade =  hoje.year - nascimento.year - ((hoje.month, hoje.day) < (nascimento.month, nascimento.day))
    naturalidade=fake.city()
    nacionalidade=fake.country()
    sexo=random.choice(["Masculino", "Feminino"])
    cor=fake.color_name()
    estadocivil=random.choice(["Solteiro(a)", "Casado(a)", "Divorciado(a)", "Viúvo(a)"])
    profissao=fake.job()
    telefone1=fake.phone_number()
    telefone2=fake.phone_number()
    email1=fake.email()
    email2=fake.email()
    cpf=fake.unique.random_int(min=10000000000, max=99999999999)
    rg=fake.random_int(min=100000000, max=999999999)
    rg_emissor=fake.random_element(elements=("SSP", "DETRAN", "IFP", "PF"))
    cns=fake.random_int(min=100000000000000, max=999999999999999)
    cep=fake.zipcode()
    endereco=fake.address()
    mae=fake.first_name_female()
    pai=fake.first_name_male()
    responsavel=fake.name()
    observacoes=fake.text()
    data = {"nome":nome,"nascimento":nascimento.strftime('%Y-%m-%d'),"idade":idade,"naturalidade":naturalidade,
           "nacionalidade":nacionalidade,"sexo":sexo,"cor":cor,"estadocivil":estadocivil, "profissao":profissao,
            "telefone1":telefone1,"telefone2":telefone2,"email1":email1,"email2":email2,"cpf":cpf,"rg":rg,
             "rg_emissor":rg_emissor,"cns":cns,"cep":cep,"endereco":endereco,"mae":mae,"pai":pai,
              "responsavel":responsavel,"observacoes":observacoes}
    r = requests.put(url,headers=headers,json = data)
    print(r.text)

# %%
# lista pacientes
url = 'http://127.0.0.1:8000/agendasis/api/pacientes/'
headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access["rodolfo"]}'}
r = requests.get(url,headers=headers)
json.loads(r.content)

# %%
# cria entradas no banco de dados ExameConsulta
url = 'http://127.0.0.1:8000/agendasis/api/pacientes/'
headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access["moiseis"]}'}
r = requests.get(url,headers=headers)
pacientes = json.loads(r.content)


fake = Faker()

hora_inicio = datetime.strptime("08:00", "%H:%M")
hora_fim = datetime.strptime("18:00", "%H:%M")
total_intervalos = int((hora_fim - hora_inicio).total_seconds() / (15 * 60))

for i in range(1000):
        time.sleep(0.05)
        paciente = random.choice(pacientes)
        urla = f'http://127.0.0.1:8000/agendasis/api/pacientes/{paciente["id"]}/agendamento/'
        intervalo_aleatorio = fake.random_int(min=0, max=total_intervalos)
        id = random.randint(0,100)
        data_agendamento = fake.date_of_birth(minimum_age=0, maximum_age=1)
        hora_agendamento = hora_inicio + timedelta(minutes=intervalo_aleatorio * 15)
        hora_agendamento = hora_agendamento.strftime('%H:%M:%S')
        tipo = random.choice(["Tipo 1", "Tipo 2", "Tipo 3", "Tipo 4"])
        medico = fake.name()
        data_checkin = None
        hora_checkin = None
        convenio = random.choice(["Conv 1", "Conv 2", "Conv 3", "Conv 4"])
        numcarteirinha = fake.random_int(min=1000000, max=9999999)
        validade = fake.date()
        observacoes = fake.text()
        data = {"paciente":id,"data_agendamento":data_agendamento.strftime('%Y-%m-%d'),"hora_agendamento":hora_agendamento,
                "tipo":tipo,"medico":medico,"data_checkin":data_checkin,"hora_checkin":hora_checkin,"convenio":convenio,
                "numcarteirinha":numcarteirinha,"validade":validade,"observacoes":observacoes}
        r = requests.post(urla,headers=headers,json = data)
        if not r.ok:
                print(paciente["id"],json.loads(r.content))
# Out:
# 109 {'paciente': ['Invalid pk "0" - object does not exist.']}
# 182 {'paciente': ['Invalid pk "0" - object does not exist.']}
# 179 {'paciente': ['Invalid pk "0" - object does not exist.']}

# %%
url = 'http://127.0.0.1:8000/agendasis/api/pacientes/'
headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access["moiseis"]}'}
r = requests.get(url,headers=headers)
pacientes = json.loads(r.content)

urla = f'http://127.0.0.1:8000/agendasis/api/pacientes/{pacientes[0]["id"]}/agendamento/'        
r = requests.get(urla,headers=headers)
consultas = json.loads(r.content)
consultas


consultas[0]["numcarteirinha"]='00000'

urla = f'http://127.0.0.1:8000/agendasis/api/pacientes/{pacientes[0]["id"]}/agendamento/{consultas[0]["id"]}/'        
r = requests.put(urla,headers=headers,json = consultas[0] )
json.loads(r.content)

urla = f'http://127.0.0.1:8000/agendasis/api/pacientes/{pacientes[0]["id"]}/agendamento/{consultas[5]["id"]}/'        
r = requests.delete(urla,headers=headers)
json.loads(r.content)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /Users/moi6/GitHub/Desenvolvimento/backend/agenda/zutils/CriaPacientes.ipynb Célula 7 line 2
#      <a href='vscode-notebook-cell:/Users/moi6/GitHub/Desenvolvimento/backend/agenda/zutils/CriaPacientes.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a> urla = f'http://127.0.0.1:8000/agendasis/api/pacientes/{pacientes[0]["id"]}/agendamento/{consultas[5]["id"]}/'
#      <a href='vscode-notebook-cell:/Users/moi6/GitHub/Desenvolvimento/backend/agenda/zutils/CriaPacientes.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a> r = requests.delete(urla,headers=headers)
# ---> <a href='vscode-notebook-cell:/Users/moi6/GitHub/Desenvolvimento/backend/agenda/zutils/CriaPacientes.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> json.loads(r.content)
#
# File ~/opt/miniconda3/envs/centelha/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/opt/miniconda3/envs/centelha/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/opt/miniconda3/envs/centelha/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = 'http://127.0.0.1:8000/agendasis/api/agenda/?data_inicio=2023-11-20&data_fim=2023-11-21'
headers = {'Content-Type': 'application/json','Authorization': f'Bearer {access["rodolfo"]}'}
r = requests.get(url,headers=headers)
json.loads(r.content)
# Out:
# [{'paciente': 15,
#   'id': 1135,
#   'data_agendamento': '2023-11-20',
#   'hora_agendamento': '11:45:00',
#   'tipo': 'Tipo 2',
#   'medico': 'Richard Roberson',
#   'data_checkin': None,
#   'hora_checkin': None,
#   'convenio': 'Conv 2',
#   'numcarteirinha': '1476807',
#   'validade': '1974-06-17',
#   'observacoes': 'Attack author year measure cultural. Movie base end language admit fight price.\nRich test peace federal left. Specific must gun contain model season natural key.',
#   'paciente_info': {'nome': 'Alexis Morris DVM',
#    'cpf': '86586538462',
#    'telefone1': '7166650296'}}]
